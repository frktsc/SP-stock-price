# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data_MSFT = pd.read_excel(r"stocksprice-furkanalitasci.xlsx",sheet_name="MSFT")
Data_Tesla = pd.read_excel(r"stocksprice-furkanalitasci.xlsx",sheet_name="Tesla")
Data_Apple = pd.read_excel(r"stocksprice-furkanalitasci.xlsx",sheet_name="Apple")
Data_SP500 = pd.read_excel(r"stocksprice-furkanalitasci.xlsx",sheet_name="SP500")
Data_Combined = pd.read_excel(r"stocksprice-furkanalitasci.xlsx",sheet_name="combined")

# %%
Data_Tesla.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2018-01-02  20.799999  21.474001  20.733334  21.368668  21.368668
# 1 2018-01-03  21.400000  21.683332  21.036667  21.150000  21.150000
# 2 2018-01-04  20.858000  21.236668  20.378668  20.974667  20.974667
# 3 2018-01-05  21.108000  21.149332  20.799999  21.105333  21.105333
# 4 2018-01-08  21.066668  22.468000  21.033333  22.427334  22.427334
#
#       Volume   %change
# 0   65283000       NaN
# 1   67822500  0.028846
# 2  149194500 -0.025327
# 3   68868000  0.011986
# 4  147891000 -0.001958

# %%
Data_Tesla.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1278  1278.000000  1278.000000  1278.000000
# mean   2020-07-15 22:23:05.915492864   131.895211   134.958406   128.511830
# min              2018-01-02 00:00:00    12.073333    12.445333    11.799333
# 25%              2019-04-10 06:00:00    21.088166    21.509167    20.684500
# 50%              2020-07-16 12:00:00    96.573334   100.321666    94.266998
# 75%              2021-10-20 18:00:00   234.916672   239.542503   229.159164
# max              2023-01-30 00:00:00   411.470001   414.496674   405.666656
# std                              NaN   117.166580   119.816919   114.137511
#
#              Close    Adj Close        Volume      %change
# count  1278.000000  1278.000000  1.278000e+03  1277.000000
# mean    131.790281   131.790281  1.333573e+08     0.002625
# min      11.931333    11.931333  2.940180e+07    -0.210924
# ...

# %%
tesla_skewness = Data_Tesla['Close'].skew()
print("skewness:", tesla_skewness)

teskla_kurtosis = Data_Tesla['Close'].kurtosis()
print("Kurtosis:", teskla_kurtosis)
# Out:
# skewness: 0.46879229762979396
# Kurtosis: -1.2603710575378417

# %%
print(Data_Tesla.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1278 non-null   datetime64[ns]
#  1   Open       1278 non-null   float64
#  2   High       1278 non-null   float64
#  3   Low        1278 non-null   float64
#  4   Close      1278 non-null   float64
#  5   Adj Close  1278 non-null   float64
#  6   Volume     1278 non-null   int64
#  7   %change    1277 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 80.0 KB
# None

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=Data_Tesla['Close'], kde=True, bins=50, color='purple', edgecolor='black')

plt.xlabel('Tesla Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Tesla', fontsize=16)
plt.show()

# %%
Data_Apple.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2018-01-02  42.540001  43.075001  42.314999  43.064999  40.950493
# 1 2018-01-03  43.132500  43.637501  42.990002  43.057499  40.943363
# 2 2018-01-04  43.134998  43.367500  43.020000  43.257500  41.133537
# 3 2018-01-05  43.360001  43.842499  43.262501  43.750000  41.601860
# 4 2018-01-08  43.587502  43.902500  43.482498  43.587502  41.447338
#
#       Volume   %change
# 0  102223600       NaN
# 1  118071600  0.013928
# 2   89738400  0.000058
# 3   94640000  0.005216
# 4   82271200  0.005247

# %%
print(Data_Apple.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1278 non-null   datetime64[ns]
#  1   Open       1278 non-null   float64
#  2   High       1278 non-null   float64
#  3   Low        1278 non-null   float64
#  4   Close      1278 non-null   float64
#  5   Adj Close  1278 non-null   float64
#  6   Volume     1278 non-null   int64
#  7   %change    1277 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 80.0 KB
# None

# %%
Data_Apple.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1278  1278.000000  1278.000000  1278.000000
# mean   2020-07-15 22:23:05.915492864    98.574104    99.778017    97.422742
# min              2018-01-02 00:00:00    35.994999    36.430000    35.500000
# 25%              2019-04-10 06:00:00    51.070625    51.547500    50.685625
# 50%              2020-07-16 12:00:00    95.087497    96.307499    93.983749
# 75%              2021-10-20 18:00:00   142.699997   144.329998   140.844994
# max              2023-01-30 00:00:00   182.630005   182.940002   179.119995
# std                              NaN    46.176136    46.773050    45.566825
#
#              Close    Adj Close        Volume      %change
# count  1278.000000  1278.000000  1.278000e+03  1277.000000
# mean     98.646516    97.388233  1.162205e+08     0.001175
# min      35.547501    34.309586  3.519590e+07    -0.086602
# ...

# %%
apple_skewness = Data_Apple['Close'].skew()
print("skewness:", apple_skewness)

apple_kurtosis = Data_Apple['Close'].kurtosis()
print("Kurtosis:", apple_kurtosis)
# Out:
# skewness: 0.12178385411584634
# Kurtosis: -1.5799834159771067

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=Data_Apple['Close'], kde=True, bins=50, color='green', edgecolor='black')

plt.xlabel('Apple Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Apple', fontsize=16)
plt.show()

# %%
Data_SP500.head()
# Out:
#            Date     Open     High      Low   Close*  Adj Close**      Volume  \
# 0  Jan 02, 2018  2683.73  2695.89  2682.36  2695.81      2695.81  3397430000
# 1  Jan 03, 2018  2697.85  2714.37  2697.77  2713.06      2713.06  3544030000
# 2  Jan 04, 2018  2719.31  2729.29  2719.07  2723.99      2723.99  3697340000
# 3  Jan 05, 2018  2731.33  2743.45  2727.92  2743.15      2743.15  3239280000
# 4  Jan 08, 2018  2742.67  2748.51  2737.60  2747.71      2747.71  3246160000
#
#     %change
# 0       NaN
# 1  0.005234
# 2  0.007892
# 3  0.004401
# 4  0.004135

# %%
Data_Combined.head()
# Out:
#         MSFT   MS%chng      Tesla  Tesl%chng      Apple  App%chng    SP500  \
# 0  86.129997       NaN  20.799999        NaN  42.540001       NaN  2683.73
# 1  86.059998 -0.000813  21.400000   0.028846  43.132500  0.013928  2697.85
# 2  86.589996  0.006158  20.858000  -0.025327  43.134998  0.000058  2719.31
# 3  87.660004  0.012357  21.108000   0.011986  43.360001  0.005216  2731.33
# 4  88.199997  0.006160  21.066668  -0.001958  43.587502  0.005247  2742.67
#
#     SP%chng
# 0       NaN
# 1  0.005234
# 2  0.007892
# 3  0.004401
# 4  0.004135

# %%
Data_MSFT.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume  \
# 0 2018-01-02  86.129997  86.309998  85.500000  85.949997  80.940384  22483800
# 1 2018-01-03  86.059998  86.510002  85.970001  86.349998  81.317093  26061400
# 2 2018-01-04  86.589996  87.660004  86.570000  87.110001  82.032776  21912000
# 3 2018-01-05  87.660004  88.410004  87.430000  88.190002  83.049843  23407100
# 4 2018-01-08  88.199997  88.580002  87.599998  88.279999  83.134590  22113000
#
#     %change  Unnamed: 8  Unnamed: 9 Unnamed: 10  Unnamed: 11
# 0       NaN         NaN         NaN         NaN          NaN
# 1 -0.081271         NaN         NaN         NaN          NaN
# 2  0.006158         NaN         NaN         NaN          NaN
# 3  0.012357         NaN         NaN   Adj Close          NaN
# 4  0.006160         NaN         NaN         NaN          NaN

# %%
print(Data_MSFT.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1278 non-null   datetime64[ns]
#  1   Open         1278 non-null   float64
#  2   High         1278 non-null   float64
#  3   Low          1278 non-null   float64
#  4   Close        1278 non-null   float64
#  5   Adj Close    1278 non-null   float64
#  6   Volume       1278 non-null   int64
#  7   %change      1277 non-null   float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  14 non-null     object
#  11  Unnamed: 11  13 non-null     float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 119.9+ KB
# None

# %%
Data_MSFT.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1278  1278.000000  1278.000000  1278.000000
# mean   2020-07-15 22:23:05.915492864   194.470900   196.522676   192.301847
# min              2018-01-02 00:00:00    86.059998    86.309998    83.830002
# 25%              2019-04-10 06:00:00   120.209999   120.827499   119.412503
# 50%              2020-07-16 12:00:00   203.580002   205.190002   201.315002
# 75%              2021-10-20 18:00:00   255.482506   257.789994   252.340000
# max              2023-01-30 00:00:00   344.619995   349.670013   342.200012
# std                              NaN    74.232396    75.002651    73.399757
#
#              Close    Adj Close        Volume      %change  Unnamed: 8  \
# count  1278.000000  1278.000000  1.278000e+03  1277.000000         0.0
# mean    194.510548   190.826784  3.026779e+07     0.000917         NaN
# ...

# %%
mstf_skewness = Data_MSFT['Close'].skew()
print("skewness:", mstf_skewness)

mstf_kurtosis = Data_MSFT['Close'].kurtosis()
print("Kurtosis:", mstf_kurtosis)
# Out:
# skewness: 0.14721657870433513
# Kurtosis: -1.2906775467523983

# %%
plt.figure(figsize=(10, 6))

sns.histplot(data=Data_MSFT['Close'], kde=True, bins=50, color='orange', edgecolor='black')

plt.xlabel('MSFT Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of MSFT', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(14, 6))

plt.plot(Data_MSFT['Date'], Data_MSFT['Close'], label='MSTF', color='blue')
plt.plot(Data_Tesla['Date'], Data_Tesla['Close'], label='Tesla', color='red')
plt.plot(Data_Apple['Date'], Data_Apple['Close'], label='Apple', color='green')

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock Prices Over Time')

plt.legend()
plt.show()

# %% [markdown]
# ### REGRESSION ANALYSIS FOR TESLA ###

# %%
Data_Combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278 entries, 0 to 1277
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MSFT       1278 non-null   float64
#  1   MS%chng    1277 non-null   float64
#  2   Tesla      1278 non-null   float64
#  3   Tesl%chng  1277 non-null   float64
#  4   Apple      1278 non-null   float64
#  5   App%chng   1277 non-null   float64
#  6   SP500      1278 non-null   float64
#  7   SP%chng    1277 non-null   float64
# dtypes: float64(8)
# memory usage: 80.0 KB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Data_Combined.head()
# Out:
#         MSFT   MS%chng      Tesla  Tesl%chng      Apple  App%chng    SP500  \
# 0  86.129997       NaN  20.799999        NaN  42.540001       NaN  2683.73
# 1  86.059998 -0.000813  21.400000   0.028846  43.132500  0.013928  2697.85
# 2  86.589996  0.006158  20.858000  -0.025327  43.134998  0.000058  2719.31
# 3  87.660004  0.012357  21.108000   0.011986  43.360001  0.005216  2731.33
# 4  88.199997  0.006160  21.066668  -0.001958  43.587502  0.005247  2742.67
#
#     SP%chng
# 0       NaN
# 1  0.005234
# 2  0.007892
# 3  0.004401
# 4  0.004135

# %%
Data_Combined.isna().sum()
# Out:
# MSFT         0
# MS%chng      1
# Tesla        0
# Tesl%chng    1
# Apple        0
# App%chng     1
# SP500        0
# SP%chng      1
# dtype: int64

# %%
Data_Combined.dropna(axis=0,inplace=True)

# %%
X_tesla=Data_Combined['Tesl%chng'].values.reshape(-1,1)
y=Data_Combined['SP%chng']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tesla, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions on the test set
y_pred = model.predict(X_test)

# Evaluating the model's performance
from sklearn.metrics import mean_squared_error, r2_score
print("Mean squared error (MSE) for Tesla: ", mean_squared_error(y_test, y_pred))
print("Coefficient of determination (R^2) for Tesla: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error (MSE) for Tesla:  0.00011403603484222923
# Coefficient of determination (R^2) for Tesla: 0.29

# %%
plt.scatter(X_test, y_test, color='black', label='Actual values')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Predictions')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Model For Tesla and S&P500')
plt.legend()
plt.show()

# %%
covariance = np.cov(Data_Combined['Tesl%chng'], Data_Combined['SP%chng'])
cov_stock_market = covariance[0, 1]
var_market = covariance[1, 1]

beta_tesla = cov_stock_market / var_market
print(f"Tesla Beta Value: {beta_tesla}")
# Out:
# Tesla Beta Value: 1.817793485764997

# %% [markdown]
# ### REGRESSION ANALYSIS FOR APPLE ###

# %%
X_Apple=Data_Combined['App%chng'].values.reshape(-1,1)
y=Data_Combined['SP%chng']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_Apple, y, test_size=0.2, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
print("Mean squared error (MSE) for Apple: %.2f" % mean_squared_error(y_test, y_pred))
print("Coefficient of determination (R^2) for Apple: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error (MSE) for Apple: 0.00
# Coefficient of determination (R^2) for Apple: 0.56

# %%
plt.scatter(X_test, y_test, color='black', label='Actual values')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Predictions')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Model For APPLE and S&P500')
plt.legend()
plt.show()

# %%
covariance = np.cov(Data_Combined['App%chng'], Data_Combined['SP%chng'])
cov_stock_market = covariance[0, 1]
var_market = covariance[1, 1]

apple_beta = cov_stock_market / var_market
print(f"Apple Beta Value: {apple_beta}")
# Out:
# Apple Beta Value: 1.3292067722064769

# %% [markdown]
# ### REGRESSION ANALYSIS FOR MSFT ###

# %%
X_MSFT=Data_Combined['MS%chng'].values.reshape(-1,1)
y=Data_Combined['SP%chng']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_MSFT, y, test_size=0.2, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
print("Mean squared error (MSE) for MSFT: %.2f" % mean_squared_error(y_test, y_pred))
print("Coefficient of determination (R^2) for MSFT: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error (MSE) for MSFT: 0.00
# Coefficient of determination (R^2) for MSFT: 0.60

# %%
plt.scatter(X_test, y_test, color='black', label='Actual values')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Predictions')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Model For Microsoft and S&P500')
plt.legend()
plt.show()

# %%
covariance = np.cov(Data_Combined['MS%chng'], Data_Combined['SP%chng'])
cov_stock_market = covariance[0, 1]
var_market = covariance[1, 1]

meft_beta = cov_stock_market / var_market
print(f"MSFT Beta Value: {meft_beta}")
# Out:
# MSFT Beta Value: 1.213894899875019

# %%
import matplotlib.pyplot as plt
import pandas as pd


# Set the figure size and create subplots
plt.figure(figsize=(12, 8))

# First subplot for Tesla's closing price
plt.subplot(3, 1, 1)  # (nrows, ncols, index)
plt.plot(Data_Tesla['Date'], Data_Tesla['Close'], label='Tesla', color='orange')
plt.title('Tesla Closing Price')
plt.legend()

# Second subplot for Microsoft's closing price
plt.subplot(3, 1, 2)  # New subplot in the second row
plt.plot(Data_MSFT['Date'], Data_MSFT['Close'], label='Microsoft', color='green')
plt.title('Microsoft Closing Price')
plt.legend()

# Third subplot for Apple's closing price
plt.subplot(3, 1, 3)  # New subplot in the third row
plt.plot(Data_Apple['Date'], Data_Apple['Close'], label='Apple', color='red')
plt.title('Apple Closing Price')
plt.xlabel('Date')
plt.legend()

# Automatically adjust the subplot params so that the subplot(s) fits in to the figure area.
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 8))

# First subplot for Tesla's closing price
plt.subplot(3, 1, 1)  # (nrows, ncols, index)
plt.plot(Data_Tesla['Date'], Data_Tesla['Volume'], label='Tesla', color='orange')
plt.title('Tesla Volume')
plt.legend()

# Second subplot for Microsoft's closing price
plt.subplot(3, 1, 2)  # New subplot in the second row
plt.plot(Data_MSFT['Date'], Data_MSFT['Volume'], label='Microsoft', color='green')
plt.title('Microsoft Volume')
plt.legend()

# Third subplot for Apple's closing price
plt.subplot(3, 1, 3)  # New subplot in the third row
plt.plot(Data_Apple['Date'], Data_Apple['Volume'], label='Apple', color='red')
plt.title('Apple Volume')
plt.xlabel('Date')
plt.legend()

# Automatically adjust the subplot params so that the subplot(s) fits in to the figure area.
plt.tight_layout()

plt.show()

# %%
# Assuming df is your DataFrame with the stock prices, and it has columns named 'Tesla_Close', 'Microsoft_Close', 'Apple_Close'

# Calculate daily returns
Data_Tesla['Tesla_Return'] = Data_Tesla['Close'].pct_change()
Data_MSFT['Microsoft_Return'] = Data_MSFT['Close'].pct_change()
Data_Apple['Apple_Return'] = Data_Apple['Close'].pct_change()

# Plot histograms
plt.figure(figsize=(18, 5))

# Tesla
plt.subplot(1, 3, 1)  # 1 row, 3 columns, 1st subplot
plt.hist(Data_Tesla['Tesla_Return'].dropna(), bins=30, color='orange')
plt.title('Tesla Daily Returns')
plt.xlabel('Return')
plt.ylabel('Frequency')

# Microsoft
plt.subplot(1, 3, 2)  # 1 row, 3 columns, 2nd subplot
plt.hist(Data_MSFT['Microsoft_Return'].dropna(), bins=30, color='green')
plt.title('Microsoft Daily Returns')
plt.xlabel('Return')

# Apple
plt.subplot(1, 3, 3)  # 1 row, 3 columns, 3rd subplot
plt.hist(Data_Apple['Apple_Return'].dropna(), bins=30, color='red')
plt.title('Apple Daily Returns')
plt.xlabel('Return')

# Show the plot
plt.tight_layout()
plt.show()

# %%
daily_returns_apple=Data_Apple["Close"].pct_change()
daily_returns_msft=Data_MSFT["Close"].pct_change()
daily_returns_Tesla=Data_Tesla["Close"].pct_change()

# %%
daily_returns_combined = pd.DataFrame({
    'Apple': daily_returns_apple,
    'Microsoft': daily_returns_msft,
    'Tesla': daily_returns_Tesla
})

# %%
sns.pairplot(daily_returns_combined.dropna(),kind='reg')
plt.suptitle('Daily Returns: Apple vs. Microsoft vs. Tesla', y=1.02)
plt.show()

# %%
corr_matrix = daily_returns_combined.corr()

# Heatmap çizimi için farklı bir renk paleti kullanma
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='inferno', vmin=-1, vmax=1)
plt.title('Correlation matrix of daily returns of stocks')
plt.show()
